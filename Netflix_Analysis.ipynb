# %% [markdown]
# <a href="https://colab.research.google.com/github/themodernturing/Netflix-Analysis/blob/main/Netflix_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as  pd

# %%
netflix_df = pd.read_csv('/content/drive/MyDrive/netflix_data.csv')

# %%
netflix_df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix_subset = netflix_df[netflix_df['type'] != 'TV Show']

# %%
print(netflix_df.shape)
print(netflix_subset.shape)
# Out:
# (7787, 11)
# (5377, 11)

# %%
netflix_movies = netflix_df[['title', 'country', 'genre', 'release_year', 'duration']]
print(netflix_movies)
# Out:
#                                         title         country  \
# 0                                          3%          Brazil
# 1                                        7:19          Mexico
# 2                                       23:59       Singapore
# 3                                           9   United States
# 4                                          21   United States
# ...                                       ...             ...
# 7782                                     Zozo          Sweden
# 7783                                   Zubaan           India
# 7784                        Zulu Man in Japan             NaN
# 7785                    Zumbo's Just Desserts       Australia
# 7786  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  United Kingdom
#
#                  genre  release_year  duration
# 0     International TV          2020         4
# 1               Dramas          2016        93
# 2        Horror Movies          2011        78
# ...

# %%
short_movies = netflix_movies[netflix_movies['duration'] < 60]
print
# Out:
#                       title    country             genre  release_year  \
# 0                        3%     Brazil  International TV          2020
# 5                        46     Turkey  International TV          2016
# 11                     1983     Poland          Crime TV          2018
# 12                     1994     Mexico          Crime TV          2019
# 16                   Feb-09        NaN  International TV          2018
# ...                     ...        ...               ...           ...
# 7775             Zoids Wild      Japan      Anime Series          2018
# 7777            Zombie Dumb        NaN              Kids          2018
# 7779              Zona Rosa     Mexico  International TV          2019
# 7784      Zulu Man in Japan        NaN     Documentaries          2019
# 7785  Zumbo's Just Desserts  Australia  International TV          2019
#
#       duration
# 0            4
# 5            1
# 11           1
# 12           1
# 16           1
# ...        ...
# ...

# %%
print(short_movies['genre'].value_counts())
# Out:
# International TV        690
# Crime TV                369
# Kids                    359
# British TV              232
# Docuseries              194
# Documentaries           151
# Anime Series            148
# TV Comedies             110
# Children                107
# Stand-Up                105
# Reality TV              102
# TV Dramas                62
# Uncategorized            40
# TV Action                37
# Romantic TV              28
# Classic                  21
# Comedies                 15
# TV Shows                 12
# Dramas                   12
# TV Horror                10
# Classic Movies            8
# Action                    6
# International Movies      3
# Anime Features            3
# Spanish-Language          2
# Music                     2
# TV Sci                    1
# Horror Movies             1
# Name: genre, dtype: int64

# %%
print(short_movies['duration'].value_counts())
# Out:
# 1     1608
# 2      382
# 3      185
# 4       87
# 5       59
# 6       30
# 59      24
# 53      24
# 46      23
# 54      23
# 24      22
# 58      21
# 52      19
# 44      19
# 7       19
# 8       19
# 55      15
# 22      15
# 57      14
# 40      13
# 23      12
# 56      12
# 25      10
# 50      10
# 51      10
# 45      10
# 47      10
# 29      10
# 28      10
# 9        9
# 42       8
# 49       8
# 32       7
# 48       7
# 10       7
# 30       6
# 26       6
# 11       5
# 33       5
# 15       4
# 38       4
# 12       4
# 41       3
# 17       3
# 27       3
# 13       3
# 14       3
# 35       3
# 19       2
# 31       2
# 16       2
# 21       2
# 37       2
# 34       2
# 20       2
# 43       1
# 18       1
# 36       1
# Name: duration, dtype: int64

# %%
colors = []
for row in netflix_movies.itertuples():
  if row.genre == "Children":
    colors.append("yellow")
  elif row.genre == "Documentaries":
    colors.append("black")
  elif row.genre == "Stand-Up":
    colors.append("green")
  else:
    colors.append("red")

# %%
fig = plt.figure()
plt.scatter(netflix_movies['release_year'], netflix_movies['duration'], c=colors)
plt.xlabel('Release Year')
plt.ylabel('Duration')
plt.title('Movie Duration vs. Release Year')
plt.show()

# %%
Question = "Are movies getting shorter?"
Answer = "Yes"

print('Ques:' , Question)
print('Ans:' , Answer)
# Out:
# Ques: Are movies getting shorter?
# Ans: Yes
